# %%
df["DateTime"] = pd.to_datetime(df["Date"] + " " + df["Time"])
df.set_index("DateTime", inplace=True)

df["Global_active_power"].plot(figsize=(12,4))
plt.title("Power Usage Over Time")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df["DateTime"] = pd.to_datetime(df["Date"] + " " + df["Time"])
#       2 df.set_index("DateTime", inplace=True)
#       4 df["Global_active_power"].plot(figsize=(12,4))
#
# NameError: name 'pd' is not defined
